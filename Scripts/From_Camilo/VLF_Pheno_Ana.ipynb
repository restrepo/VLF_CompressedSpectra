# %%
#from IPython.core.interactiveshell import InteractiveShell
import ROOT
import os
import commands
import math
import pickle
# Out:
# Welcome to JupyROOT 6.10/05

# %%
ROOT.gROOT.ProcessLine("#include <math.h>");
ROOT.gSystem.Load("libDelphes");

# %%
from CutAnalyzer_lib import save_obj

# %%
# %jsroot on

# %%
#If input samples is a list use 0 if is just one file use 1 on TSam variable
def ChainConstructor(path, ListOfFolders):
    DTrees={};
    for Folder in ListOfFolders:
        #Path=path+Folder+"/*_events1.root"
        Path=path+Folder+"/*.root"
        MainChain=ROOT.TChain("Delphes");
        MainChain.Add(Path)
        print "add ", Path
        DTrees[Folder]=MainChain;
    return DTrees

# %%
#The backgrounds
Path1= "/home/rsiii/SSSFDM/VLF/Background/"; 
ListOfFolders = ["wjets","singletop"];
#The Signal
Path2= "/home/rsiii/SSSFDM/VLF/Signal/"; 
FolderSignal=["signal_10090"];

# %%
DBack={}
DTrees={}
DSignal={}
DBack=ChainConstructor(Path1,ListOfFolders)
DSignal=ChainConstructor(Path2,FolderSignal)
DTrees["BckgndW+Jets"]=DBack["wjets"]
#DTrees["BckgndSingleTop"]=DBack["singletop"]
DTrees["Signal"]=DSignal["signal_10090"]
# Out:
# add  /home/rsiii/SSSFDM/VLF/Background/wjets/*.root
# add  /home/rsiii/SSSFDM/VLF/Background/singletop/*.root
# add  /home/rsiii/SSSFDM/VLF/Signal/signal_10090/*.root

# %%
LsOfCuts={
            "Jet":
                {
                    #Leading Jet PT greater than 60GeV, and all of them less than 100
                    "PT":[(0,">60"), "<100"],
                    "Entries":[">1","<3"]
                },
            "Muon":
                {
                    #Leading Muon PT greater than 5GeV
                    "PT":[(0,">5")],
                    #number of Muon equal to one
                    "Entries":["==1"]
                },
            "MissingET":
                {
                    #
                    "MET":[">60"]
                }
        }

# %%
LsOfCuts={
            "Jet":
                {
                    #Leading Jet PT greater than 60GeV, and all of them less than 100
                    "PT":[(0,">60")]
                },
            "Muon":
                {
                    #Leading Muon PT greater than 5GeV
                    "PT":[(0,">5")],
                    #number of Muon equal to one
                    "Entries":["==1"]
                },
            "MissingET":
                {
                    #
                    "MET":[">60"]
                }
        }

# %%
LsOfCuts
# Out:
# {'Jet': {'PT': [(0, '>60')]},
#  'MissingET': {'MET': ['>60']},
#  'Muon': {'Entries': ['==1'], 'PT': [(0, '>5')]}}

# %%
Chain=DTrees["Signal"]

# %%
LsOfPOandVOI={
                "Jet":[(0,"PT"),(1,"PT"),"Entries"],
                "Muon":[(0,"PT"),"Entries"],
                "MissingET":["MET"]
                }

# %%
LsOfPOandVOI
# Out:
# {'Jet': [(0, 'PT'), (1, 'PT'), 'Entries'],
#  'MissingET': ['MET'],
#  'Muon': [(0, 'PT'), 'Entries']}

# %%
#Debug=True
Debug=False

# %%
    #CutFlow dictionary, to keep the track of the cuts the events pass or fail 
    CutFlow={}
    #Set the deafault cutflow 
    CutFlowUser=[]
    PhOb=LsOfCuts.keys()
    #print "PhOb", PhOb
    #If is empty return error
    for i in PhOb:
        VaOfIn=LsOfCuts[i]
        #If is empty return error
        #print VaOfIn
        Cuts=VaOfIn.keys()
        #If is empty return error
        #print "Cuts", Cuts
        for j in Cuts:
            cut_base=VaOfIn[j]
            for cut_ in cut_base:
                if isinstance(cut_, tuple):
                    #print i+j+cut_[1]
                    CutFlowUser.append("Count_"+i+"["+str(cut_[0])+"]"+j+cut_[1])
                else:
                    #print i+j+cut_
                    if i=="Jet" or i=="Muon" or i=="Electron" or i=="Photon":
                        if j != "Entries":
                            CutFlowUser.append("Count_"+i+"[0]"+j+cut_)
                        else:
                            CutFlowUser.append("Count_"+i+j+cut_)
                    else:
                        CutFlowUser.append("Count_"+i+j+cut_)
    #If the cutflow have this number of Trues entries 
    Validationlen=len(CutFlowUser)
    
    
    #Create the plots
    Histograms={}
    CutUserFlagsObj= LsOfPOandVOI.keys()
    
    #The ExRootTreeReader objet
    treeReader = ROOT.ExRootTreeReader(Chain)
    numberOfEntries = treeReader.GetEntries()
        
   
    counts={}
    #PhOb=LsOfCuts.keys()
    PhyObj={}
    #Branches=["Jet","Muon","MissingET","ScalarHT","Photon","Electron"]
    #get the branches I am going to use
    for branch in PhOb:
        PhyObj[branch] = treeReader.UseBranch(branch)
        
    # Loop over events
    for entry in range(0, numberOfEntries):
        if Debug: 
            if entry==100:
                break
        flags={}
        #Get the entry
        treeReader.ReadEntry(entry)
        
        # Cuts over jets
        if LsOfCuts.has_key('Jet'):                         #Cuts over Jets?
            if Debug:
                print "Jet"
            if PhyObj["Jet"].GetEntries() > 0:              #There are any Jets in the data
                VaOfIn=LsOfCuts['Jet']                      #Which cuts over jets
                
                if VaOfIn.has_key('Entries'):
                    if Debug:
                        print "Entries"
                    Cuts=VaOfIn['Entries']
                    for cut_ in Cuts:               #run over all the Entries cuts 
                        flag=False
                        filt=cut_
                        #Evaluate the condition
                        mycode="flag = True if PhyObj['Jet'].GetEntries() "+filt+" else False" 
                        if Debug:
                            print mycode
                        exec(mycode)
                        name="Count_JetEntries"+filt
                        if flag:
                            if Debug:
                                print "Pass: "+filt
                            #Counts
                            if counts.has_key(name):
                                counts[name] += 1
                            else:
                                counts[name] = 1
                        #CutFlow    
                            flags[name] = True  
                        else:
                            if Debug:
                                print "Fail: "+filt
                            flags[name] = False 
                                            
                if VaOfIn.has_key('PT') and PhyObj["Jet"].GetEntries() > 0:                    #If ther are cut over PT
                    if Debug:
                        print "PT"
                    Cuts=VaOfIn['PT']
                    for cut_ in Cuts:               #run over all the PT cuts 
                        if isinstance(cut_, tuple):     #See if is tuple
                            if Debug:
                                print "Tuple"
                            flag=False
                            filt=cut_[1]
                            #See if there are enough entries to evaluate
                            if(PhyObj["Jet"].GetEntries() > cut_[0]):
                                jet= PhyObj["Jet"].At(cut_[0])
                                #Evaluate the condition
                                mycode="flag = True if jet.PT "+filt+" else False" 
                                exec(mycode)
                                name="Count_Jet["+str(cut_[0])+"]PT"+cut_[1]   
                            if flag:                    #Counts
                                if counts.has_key(name):
                                    counts[name] += 1
                                else:
                                    counts[name] = 1
                                #CutFlow    
                                flags[name] = True  
                            else:
                                flags[name] = False 
                            
                        else:           #Evaluate the condition for the avaible jets 
                            for l in range(0, PhyObj["Jet"].GetEntries() ):
                                jet = PhyObj["Jet"].At(l)
                                flag=False
                                filt=cut_
                                #Evaluate the condition
                                mycode="flag = True if jet.PT "+filt+" else False" 
                                exec(mycode)
                                name="Count_Jet["+str(l)+"]PT"+filt
                                if flag:                    #Counts
                                    if counts.has_key(name):
                                        counts[name] += 1
                                    else:
                                        counts[name] = 1
                                #CutFlow    
                                    flags[name] = True  
                                else:
                                    flags[name] = False
                
                if VaOfIn.has_key('Eta'):
                    print "Jet Eta Not implementet yet"
                if VaOfIn.has_key('Phi'):
                    print "Jet Phi Not implementet yet"
                if VaOfIn.has_key('Mass'):
                    print "Jet Mass Not implementet yet"
                if VaOfIn.has_key('Flavor'):
                    print "Jet Flavor Not implementet yet"
                if VaOfIn.has_key('FlavorAlgo'):
                    print "Jet FlavorAlgo Not implementet yet"
                if VaOfIn.has_key('FlavorPhys'):
                    print "Jet FlavorPhys Not implementet yet"
                if VaOfIn.has_key('BTag'):
                    print "Not BTag implementet yet"
                if VaOfIn.has_key('BTagAlgo'):
                    print "Jet BTagAlgo Not implementet yet"
                if VaOfIn.has_key('BTagPhys'):
                    print "Jet BTagPhys Not implementet yet"
                if VaOfIn.has_key('TauTag'):
                    print "Jet TauTag Not implementet yet"
                if VaOfIn.has_key('Charge'):
                    print "Jet Charge Not implementet yet"
                if VaOfIn.has_key('EhadOverEem'):
                    print "Jet EhadOverEem Not implementet yet"
                if VaOfIn.has_key('NCharged'):
                    print "Jet NCharged Not implementet yet"
                if VaOfIn.has_key('NNeutrals'):
                    print "Jet NNeutrals Not implementet yet"
            #END IF JETS >0
        #END IF JET KEY

        
        # Cuts over Leptons and Photons
        # Made general
        #creo una lista de keys de leptones y corro sobre la lista
        """
        Entries	Number of Muons in the event
        PT	muon transverse momentum
        Eta	muon pseudorapidity
        Phi	muon azimuthal angle
        T	particle arrival time of flight
        Charge	muon charge
        Particle	reference to generated particle
        IsolationVar	isolation variable
        IsolationVarRhoCorr	isolation variable
        SumPtCharged	isolation variable
        SumPtNeutral	isolation variable
        SumPtChargedPU	isolation variable
        SumPt	isolation variable
        """
        if LsOfCuts.has_key('Muon'): 
            VaOfIn=LsOfCuts['Muon']                      #Which cuts over jets
            if VaOfIn.has_key('Entries'):
                Cuts=VaOfIn['Entries']
                for cut_ in Cuts:               #run over all the Entries cuts 
                    flag=False
                    filt=cut_
                    #Evaluate the condition
                    mycode="flag = True if PhyObj['Muon'].GetEntries() "+filt+" else False" 
                    exec(mycode)
                    name="Count_MuonEntries"+filt
                    if flag:                    #Counts
                        if counts.has_key(name):
                            counts[name] += 1
                        else:
                            counts[name] = 1
                    #CutFlow    
                        flags[name] = True  
                    else:
                        flags[name] = False        
                            
            if VaOfIn.has_key('PT') and PhyObj["Muon"].GetEntries() > 0:        #If ther are cut over PT
                Cuts=VaOfIn['PT']
                for cut_ in Cuts:               #run over all the PT cuts 
                    if isinstance(cut_, tuple):     #See if is tuple
                        flag=False
                        filt=cut_[1]
                        #See if there are enough entries to evaluate
                        if(PhyObj["Muon"].GetEntries() > cut_[0]):
                            muon= PhyObj["Muon"].At(cut_[0])
                            #Evaluate the condition
                            mycode="flag = True if muon.PT "+filt+" else False" 
                            exec(mycode)
                            name="Count_Muon["+str(cut_[0])+"]PT"+cut_[1]
                        if flag:                    #Counts
                            if counts.has_key(name):
                                counts[name] += 1
                            else:
                                counts[name] = 1
                        #CutFlow    
                            flags[name] = True  
                        else:
                            flags[name] = False     
                                
                    else:           #Evaluate the condition for the avaible jets 
                        for l in range(0, PhyObj["Muon"].GetEntries() ):
                            muon = PhyObj["Muon"].At(l)
                            flag=False
                            filt=cut_
                            #Evaluate the condition
                            mycode="flag = True if muon.PT "+filt+" else False" 
                            exec(mycode)
                            name="Count_Muon["+str(l)+"]PT"+filt
                            if flag:                    #Counts
                                if counts.has_key(name):
                                    counts[name] += 1
                                else:
                                    counts[name] = 1
                            #CutFlow    
                                flags[name] = True  
                            else:
                                flags[name] = False       
                                    
     
            if VaOfIn.has_key('Eta'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('Phi'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('T'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('Charge'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('Particle'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('IsolationVar'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('IsolationVarRhoCorr'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('SumPtCharged'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('SumPtNeutral'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('SumPtChargedPU'):
                print "Muon  Not implementet yet"
            if VaOfIn.has_key('SumPt'):
                print "Muon  Not implementet yet"
         
        
        # Cuts over MET
        """ 
        MET	mising transverse energy
        Eta	mising energy pseudorapidity
        Phi	mising energy azimuthal angle
        """
        if LsOfCuts.has_key('MissingET'):                   #Cuts over MissingET?
            VaOfIn=LsOfCuts['MissingET']                      #Which cuts over jets
            if VaOfIn.has_key('MET') and PhyObj["MissingET"].GetEntries() > 0:        #If ther are cut over PT
                Cuts=VaOfIn['MET']
                for cut_ in Cuts:               #run over all the PT cuts 
                    flag=False
                    filt=cut_
                    met= PhyObj["MissingET"].At(0)
                    #Evaluate the condition
                    mycode="flag = True if met.MET "+filt+" else False" 
                    exec(mycode)
                    name="Count_MissingETMET"+filt
                    if flag:                    #Counts
                        if counts.has_key(name):
                            counts[name] += 1
                        else:
                            counts[name] = 1     
                        #CutFlow    
                        flags[name] = True  
                    else:
                        flags[name] = False      

            if VaOfIn.has_key('Eta'):
                print "MissingET Eta Not implementet yet"
            if VaOfIn.has_key('Phi'):
                print "MissingET Phi Not implementet yet"

       

        #Calue vector, see how many of the conditions are fulfilled
        value=[]
        flagFlow={}
        if Debug:
            print "\n FlagFLOW..."
        for i in CutFlowUser:
            if Debug:
                print "CutFlowUser"+i
            if flags.has_key(i):
                if Debug:
                    print "Flag: "+str(flags[i])
                if flags[i]:
                    value.append(True)
                    flagFlow[i]=True
                else:
                    value.append(False)
                    flagFlow[i]=False
            else:
                value.append(False)
                flagFlow[i]=False
        
        #Sumary of all
        CutFlow[entry]=flagFlow
        
        #Fill the histograms
        if Debug:
            print "Filling the Histograms..."
        if sum(value)==Validationlen:
            if Debug:
                print "Pass"
            for m in CutUserFlagsObj:
                if Debug:
                    print "\nObjet: "+m
                for l in range(len(LsOfPOandVOI[m])):
                    if Debug:
                        print "Variable Of Interes: "+str(LsOfPOandVOI[m][l])
                    tmpval=0
                    tmpval1=0
                    tmpval2=0
                    if isinstance(LsOfPOandVOI[m][l], tuple):
                        if Debug:
                            print "Tuple"
                        name=m+"["+str(LsOfPOandVOI[m][l][0])+"]"+LsOfPOandVOI[m][l][1]
                        tmpval1="tmpval = PhyObj['"+m+"'].At("+str(LsOfPOandVOI[m][l][0])+")"
                        exec(tmpval1)
                        mycode="tmpval2 = tmpval."+LsOfPOandVOI[m][l][1]
                        if Debug:
                            print "name: "+name
                            print "Command: "+mycode
                        try:   
                            exec(mycode)
                        except AttributeError:
                            tmpval2=0
                        if Histograms.has_key(name)==False:
                            Histograms[name]=ROOT.TH1F()
                            Histograms[name].SetName(name)
                            Histograms[name].SetTitle(name)
                        Histograms[name].Fill(tmpval2)
                        
                    else:
                        if m=="Jet" or m=="Muon" or m=="Electron" or m=="Photon":
                            if LsOfPOandVOI[m][l] != "Entries":
                                name=m+"[0]"+LsOfPOandVOI[m][l]
                                tmpval1="tmpval = PhyObj['"+m+"'].At(0)"
                                exec(tmpval1)
                                mycode="tmpval2 = tmpval."+LsOfPOandVOI[m][l]
                                if Debug:
                                    print "name: "+name
                                    print "Command: "+mycode
                                try:   
                                    exec(mycode)
                                except AttributeError:
                                    tmpval2=0
                                if Histograms.has_key(name)==False:
                                    Histograms[name]=ROOT.TH1F()
                                    Histograms[name].SetName(name)
                                    Histograms[name].SetTitle(name)
                                Histograms[name].Fill(tmpval2)    
                            else:
                                name=m+LsOfPOandVOI[m][l]
                                mycode="tmpval2 = PhyObj['"+m+"'].Get"+LsOfPOandVOI[m][l]+"()"
                                if Debug:
                                    print "name: "+name
                                    print "Command: "+mycode
                                try:   
                                    exec(mycode)
                                except AttributeError:
                                    tmpval2=0
                                if Histograms.has_key(name)==False:
                                    Histograms[name]=ROOT.TH1F()
                                    Histograms[name].SetName(name)
                                    Histograms[name].SetTitle(name)
                                Histograms[name].Fill(tmpval2)
                        else:
                            if m=="MissingET":
                                name=m+LsOfPOandVOI[m][l]
                                tmpval1="tmpval = PhyObj['"+m+"']"
                                exec(tmpval1)
                                mycode="tmpval2 = tmpval.At(0)."+LsOfPOandVOI[m][l]
                                if Debug:
                                    print "name: "+name
                                    print "Command: "+mycode
                                try:   
                                    exec(mycode)
                                except AttributeError:
                                    tmpval2=0
                                if Histograms.has_key(name)==False:
                                    Histograms[name]=ROOT.TH1F()
                                    Histograms[name].SetName(name)
                                    Histograms[name].SetTitle(name)
                                Histograms[name].Fill(tmpval2)
                            else:
                                name=m+LsOfPOandVOI[m][l]
                                tmpval1="tmpval = PhyObj['"+m+"']"
                                exec(tmpval1)
                                mycode="tmpval2 = tmpval."+LsOfPOandVOI[m][l]
                                if Debug:
                                    print "name: "+name
                                    print "Command: "+mycode
                                try:   
                                    exec(mycode)
                                except AttributeError:
                                    tmpval2=0
                                if Histograms.has_key(name)==False:
                                    Histograms[name]=ROOT.TH1F()
                                    Histograms[name].SetName(name)
                                    Histograms[name].SetTitle(name)
                                Histograms[name].Fill(tmpval2)
                    if Debug:
                        print "temp= "+str(tmpval2)
        
     
    #Save the info 
    #Save the cuts counts        
    save_obj(counts, "CutsCounts" )
    save_obj(CutFlow, "CutFlow" )

# %%
a=Histograms['JetEntries']

# %%
a.Draw()
# Out:
# Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

# %%
CutFlow
# Out:
# {0: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  1: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  2: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  3: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  4: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  5: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  6: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  7: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  8: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  9: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  10: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  11: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  12: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  13: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  14: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  15: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  16: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  17: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  18: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  19: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  20: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  21: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  22: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  23: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  24: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  25: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  26: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  27: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  28: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  29: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  30: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  31: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  32: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  33: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  34: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  35: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  36: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  37: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  38: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  39: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  40: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  41: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  42: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  43: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  44: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  45: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  46: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  47: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  48: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  49: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  50: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  51: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  52: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  53: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  54: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  55: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  56: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  57: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  58: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  59: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  60: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  61: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  62: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  63: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  64: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  65: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  66: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  67: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  68: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  69: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  70: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  71: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  72: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  73: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  74: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  75: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  76: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  77: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  78: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  79: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  80: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  81: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  82: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  83: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  84: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  85: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  86: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  87: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  88: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  89: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  90: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  91: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  92: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  93: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  94: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  95: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  96: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  97: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  98: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  99: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  100: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  101: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  102: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  103: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  104: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  105: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  106: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  107: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  108: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  109: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  110: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  111: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  112: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  113: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  114: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  115: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  116: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  117: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  118: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  119: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  120: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  121: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  122: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  123: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  124: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  125: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  126: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  127: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  128: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  129: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  130: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  131: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  132: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  133: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  134: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  135: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  136: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  137: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  138: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  139: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  140: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  141: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  142: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  143: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  144: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  145: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  146: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  147: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  148: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  149: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  150: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  151: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  152: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  153: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  154: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  155: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  156: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  157: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  158: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  159: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  160: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  161: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  162: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  163: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  164: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  165: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  166: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  167: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  168: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  169: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  170: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  171: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  172: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  173: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  174: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  175: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  176: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  177: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  178: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  179: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  180: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  181: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  182: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  183: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  184: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  185: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  186: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  187: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  188: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  189: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  190: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  191: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  192: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  193: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  194: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  195: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  196: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  197: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  198: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  199: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  200: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  201: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  202: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  203: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  204: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  205: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  206: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  207: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  208: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  209: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  210: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  211: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  212: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  213: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  214: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  215: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  216: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  217: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  218: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  219: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  220: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  221: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  222: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  223: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  224: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  225: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  226: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  227: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  228: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  229: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  230: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  231: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  232: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  233: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  234: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  235: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  236: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  237: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  238: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  239: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  240: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  241: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  242: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  243: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  244: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  245: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  246: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  247: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  248: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  249: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  250: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  251: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  252: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  253: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  254: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  255: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  256: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  257: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  258: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  259: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  260: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  261: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  262: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  263: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  264: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  265: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  266: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  267: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  268: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  269: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  270: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  271: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  272: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  273: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  274: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  275: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  276: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  277: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  278: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  279: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  280: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  281: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  282: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  283: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  284: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  285: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  286: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  287: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  288: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  289: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  290: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  291: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  292: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  293: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  294: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  295: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  296: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  297: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  298: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  299: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  300: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  301: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  302: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  303: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  304: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  305: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  306: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  307: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  308: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  309: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  310: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  311: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  312: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  313: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  314: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  315: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  316: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  317: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  318: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  319: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  320: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  321: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  322: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  323: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  324: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  325: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  326: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  327: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  328: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  329: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  330: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  331: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  332: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  333: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  334: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  335: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  336: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  337: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  338: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  339: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  340: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  341: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  342: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  343: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  344: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  345: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  346: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  347: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  348: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  349: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  350: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  351: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  352: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  353: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  354: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  355: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  356: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  357: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  358: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  359: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  360: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  361: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  362: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  363: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  364: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  365: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  366: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
# ...
#  878: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  879: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  880: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  881: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  882: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  883: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  884: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  885: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  886: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  887: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  888: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  889: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  890: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  891: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  892: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  893: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  894: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  895: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  896: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  897: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  898: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  899: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  900: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  901: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  902: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  903: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  904: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  905: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  906: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  907: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  908: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  909: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  910: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  911: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  912: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  913: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  914: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  915: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  916: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  917: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  918: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  919: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  920: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  921: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  922: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  923: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  924: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  925: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  926: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  927: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  928: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  929: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  930: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  931: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  932: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  933: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  934: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  935: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  936: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  937: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  938: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  939: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  940: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  941: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  942: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  943: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  944: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  945: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  946: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  947: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  948: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  949: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  950: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  951: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  952: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  953: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  954: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  955: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  956: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  957: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  958: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  959: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  960: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  961: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  962: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  963: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  964: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  965: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  966: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  967: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  968: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  969: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  970: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  971: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  972: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  973: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  974: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  975: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  976: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  977: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  978: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': False},
#  979: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  980: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  981: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  982: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  983: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  984: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  985: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  986: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  987: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  988: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  989: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  990: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  991: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  992: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  993: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  994: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  995: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  996: {'Count_Jet[0]PT>60': False,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': True,
#   'Count_Muon[0]PT>5': True},
#  997: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  998: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': True,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': False},
#  999: {'Count_Jet[0]PT>60': True,
#   'Count_MissingETMET>60': False,
#   'Count_MuonEntries==1': False,
#   'Count_Muon[0]PT>5': True},
#  ...}

# %%
CutFlowUser
# Out:
# ['Count_Muon[0]PT>5',
#  'Count_MuonEntries==1',
#  'Count_MissingETMET>60',
#  'Count_Jet[0]PT>60']

# %%
Validationlen
# Out:
# 4

# %%
value=[True, True, True, True]

# %%
Debug
# Out:
# True

# %%
tmpval
# Out:
# 0

# %%
CutUserFlagsObj
# Out:
# ['Muon', 'MissingET', 'Jet']

# %%
Histograms.has_key("camilo")==False
# Out:
# True

# %%
histoKeys=Histograms.keys()
for j in histoKeys:
    #print Histograms[j]
    mycode="flag = True if jet.PT "+filt+" else False" 
    print mycode
    #exec(mycode)
# Out:
# flag = True if jet.PT >60 else False
# flag = True if jet.PT >60 else False
# flag = True if jet.PT >60 else False
# flag = True if jet.PT >60 else False
# flag = True if jet.PT >60 else False
# flag = True if jet.PT >60 else False

# %%
histoKeys[0]
# Out:
# 'Jet[1]PT'

# %%
a=Histograms[j]

# %%
a.Fill()

# %%
CutUserFlagsObj= LsOfPOandVOI.keys()
LsOfPOandVOI

# %%
LsOfPOandVOI['Muon']

# %%
CutUserFlagsObj= LsOfPOandVOI.keys()
for m in CutUserFlagsObj:
    #print m
    #print LsOfPOandVOI[m]
    for l in range(len(LsOfPOandVOI[m])):
        #print
        
        if isinstance(LsOfPOandVOI[m][l], tuple):
            tupla=LsOfPOandVOI[m][l]
            name="Count_"+m+"["+str(LsOfPOandVOI[m][l][0])+"]"+LsOfPOandVOI[m][l][1]
            print name
        else:
            name="Count_"+m+LsOfPOandVOI[m][l]
            print name

# %%
LsOfPOandVOI['Muon'][0][0]

# %%
LsOfPOandVOI[m][l]

# %%
len(LsOfPOandVOI[m])

# %%
CutUserFlagsObj=0

# %%
CutUserFlagsObj

# %%
CutFlags=flags.keys()

# %%
CutFlags

# %%
CutFlowUser=[]
PhOb=LsOfCuts.keys()
#print "PhOb", PhOb
#If is empty return error
for i in PhOb:
    VaOfIn=LsOfCuts[i]
    #If is empty return error
    #print VaOfIn
    Cuts=VaOfIn.keys()
    #If is empty return error
    #print "Cuts", Cuts
    for j in Cuts:
        cut_base=VaOfIn[j]
        for cut_ in cut_base:
            if isinstance(cut_, tuple):
                #print i+j+cut_[1]
                CutFlowUser.append("Count_"+i+"["+str(cut_[0])+"]"+j+cut_[1])
            else:
                #print i+j+cut_
                if i=="Jet" or i=="Muon" or i=="Electron" or i=="Photon":
                    if j != "Entries":
                        CutFlowUser.append("Count_"+i+"[0]"+j+cut_)
                    else:
                        CutFlowUser.append("Count_"+i+j+cut_)
                else:
                    CutFlowUser.append("Count_"+i+j+cut_)

# %%
Validationlen=len(CutFlowUser)

# %%
flags

# %%
flags['Count_Muon[0]PT>5']

# %%
flags.keys()
CutFlow={}
value=[]
for i in CutFlowUser:
    print i
    if flags.has_key(i):
        print flags[i]
        if flags[i]:
            value.append(True)
        else:
            value.append(False)
    else:
        value.append(False)

# %%
sum(value)

# %%
        #Create the plots
        Histograms={}
        CutUserFlagsObj= LsOfPOandVOI.keys()
        for m in CutUserFlagsObj:
        #print m
        #print LsOfPOandVOI[m]
            for l in range(len(LsOfPOandVOI[m])):
            #print
                if isinstance(LsOfPOandVOI[m][l], tuple):
                    name=m+"["+str(LsOfPOandVOI[m][l][0])+"]"+LsOfPOandVOI[m][l][1]
                    #print name
                    Histograms[name]=ROOT.TH1F()
                else:
                    if m=="Jet" or m=="Muon" or m=="Electron" or m=="Photon":
                        if LsOfPOandVOI[m][l] != "Entries":
                            name=m+"[0]"+LsOfPOandVOI[m][l]
                            #print name
                            Histograms[name]=ROOT.TH1F()
                            Histograms[name].SetName(name)
                            Histograms[name].SetTitle(name)
                        else:
                            name=m+LsOfPOandVOI[m][l]
                            #print name
                            Histograms[name]=ROOT.TH1F()
                    else:
                        name=m+LsOfPOandVOI[m][l]
                        #print name
                        Histograms[name]=ROOT.TH1F()

# %%
Histograms

# %%
a=Histograms['JetEntries']

# %%
a.SetName('JetEntries')
a.Fill

# %%
# Book histograms
histJetPT = ROOT.TH1F("jet_pt", "jet P_{T}", 100, 0.0, 100.0)
histMass = ROOT.TH1F("mass", "M_{inv}(e_{1}, e_{2})", 100, 40.0, 140.0)
histJetPT.Fill(jet.PT)
